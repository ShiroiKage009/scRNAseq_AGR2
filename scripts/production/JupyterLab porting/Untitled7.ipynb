# %%
import scanpy as sc

# %%
out_path = 'S:/data cache/code_in_out/agr2/script_7_out/'

# %%
adata = sc.read_h5ad(out_path + 'all_leidens_20241115.h5ad')

# %%
str(adata)
# Out:
# "AnnData object with n_obs × n_vars = 2727 × 1773\n    obs: 'sample_id', 'SampleID', 'Patient', 'Biopsies', 'Site', 'Inflammation', 'Age', 'Sex', 'doublet_scores', 'predicted_doublets', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_rp', 'pct_counts_rp', 'total_counts_hb', 'pct_counts_hb', 'total_counts_ig', 'pct_counts_ig', 'S_score', 'G2M_score', 'phase', 'cellbarcode', 'n_genes', 'leiden_0.1', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4', 'leiden_0.5', 'leiden_0.6', 'leiden_0.7', 'leiden_0.8', 'leiden_0.9', 'leiden_1.0', 'leiden_1.1', 'leiden_1.2', 'leiden_1.3'\n    var: 'gene_ids', 'feature_types', 'hb', 'ig', 'rp', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'hvg_exclude', 'gene_name', 'mean', 'std'\n    uns: 'hvg', 'leiden_0.1', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4', 'leiden_0.5', 'leiden_0.6', 'leiden_0.7', 
# ...

# %%
sc.pl.umap(adata)
